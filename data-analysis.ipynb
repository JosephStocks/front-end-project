# %%
# %pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 3.6 MB/s eta 0:00:011
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 13.9 MB/s eta 0:00:01
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 10.1 MB/s eta 0:00:01
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.2-py2.py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 59.4 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2020.12.5-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 18.1 MB/s eta 0:00:01
# Installing collected packages: chardet, idna, urllib3, certifi, requests
# Successfully installed certifi-2020.12.5 chardet-4.0.0 idna-2.10 requests-2.25.1 urllib3-1.26.2
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/jstocks/.pyenv/versions/3.7.9/bin/python3.7 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

params = {"words": 10, "paragraphs": 1, "format": "json"}

response = requests.get(f"https://alexnormand-dino-ipsum.p.rapidapi.com/", params=params,
 headers={
   "X-RapidAPI-Host": "alexnormand-dino-ipsum.p.rapidapi.com",
   "X-RapidAPI-Key": "4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
 }
)

print (type(response.json()))
print(response.json())
# Out:
# <class 'dict'>
# {'message': 'You are not subscribed to this API.'}

# %%
response = requests.get("https://api.census.gov/data/2019/acs/acs5?get=NAME,B01003_001E&for=public%20use%20microdata%20area:*&in=state:48&key=edf70f15a37d771191e6f4d62aab1871d9182206")

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# [['NAME', 'B01003_001E', 'state', 'public use microdata area'],
#  ['San Antonio City (Northwest)--Between Loop TX-1604 & Loop I-410 PUMA, Texas',
#   '128629',
#   '48',
#   '05910'],
#  ['San Antonio City (North), Hollywood Park Town & Shavano Park City PUMA; Texas',
#   '127780',
#   '48',
#   '05911'],
#  ['San Antonio City (Northeast)--Between Loop TX-1604 & Loop I-410 PUMA, Texas',
#   '113022',
#   '48',
#   '05912'],
#  ['San Antonio City (Northwest)--Inside Loop I-410 PUMA, Texas',
#   '112712',
#   '48',
#   '05904'],
#  ['Texoma COG--Grayson, Cooke & Fannin Counties PUMA; Texas',
#   '205592',
#   '48',
#   '00800'],
#  ['Hidalgo County (Southeast)--Weslaco & Mercedes Cities PUMA, Texas',
#   '110772',
#   '48',
#   '06801'],
#  ['Hidalgo County (South Central)--Pharr, San Juan & Hidalgo Cities PUMA; Texas',
#   '134227',
#   '48',
#   '06803'],
#  ['Hidalgo County (Southwest)--Mission City PUMA, Texas',
#   '114436',
#   '48',
#   '06806'],
#  ['Hidalgo County (North & West) PUMA, Texas', '113972', '48', '06807'],
#  ['Hidalgo County (Central)--McAllen City PUMA, Texas',
#   '140488',
#   '48',
#   '06805'],
#  ['Hidalgo County (East)--Alamo & Donna Cities PUMA, Texas',
#   '117521',
#   '48',
#   '06802'],
#  ['Hidalgo County (North Central)--Edinburg City PUMA, Texas',
#   '123760',
#   '48',
#   '06804'],
#  ['Orange & Hardin Counties PUMA, Texas', '140834', '48', '04200'],
#  ['Central Texas COG--Bell County (West)--Killeen & Harker Heights Cities PUMA, Texas',
#   '170995',
#   '48',
#   '03501'],
#  ['Heart of Texas COG--McLennan County--Waco (Outer), Hewitt & Robinson Cities PUMA; Texas',
#   '142747',
#   '48',
#   '03802'],
#  ['Houston City (Southwest)--Between Loop I-610 & Beltway TX-8 PUMA, Texas',
#   '115478',
#   '48',
#   '04616'],
#  ['South Plains Association of Governments (Outside Lubbock County) PUMA, Texas',
#   '128390',
#   '48',
#   '00400'],
#  ['East Texas COG (Southeast)--Rusk, Cherokee & Panola Counties PUMA; Texas',
#   '129200',
#   '48',
#   '01700'],
#  ['Deep East Texas COG (Central)--Angelina & Nacogdoches Counties PUMA, Texas',
#   '152661',
#   '48',
#   '04000'],
#  ['Central Texas COG (West), Burnet & Llano Counties PUMA; Texas',
#   '182931',
#   '48',
#   '03400'],
#  ['Fort Bend County (North)--Mission Bend (Southwest), Cinco Ranch & Four Corners PUMA; Texas',
#   '161928',
#   '48',
#   '04904'],
#  ['Austin City (North) PUMA, Texas', '114280', '48', '05302'],
#  ['San Antonio City (West)--Between Loop TX-1604 & Loop I-410 PUMA, Texas',
#   '123606',
#   '48',
#   '05908'],
#  ['Houston City (North) & Aldine--Between Loop I-610 & Beltway TX-8 PUMA, Texas',
#   '105733',
#   '48',
#   '04608'],
#  ['Parker County PUMA, Texas', '133811', '48', '02400'],
#  ['Houston-Galveston Area Council--Montgomery County (Northeast)--Conroe City (East) PUMA, Texas',
#   '156735',
#   '48',
#   '04501'],
#  ['Houston-Galveston Area Council--Montgomery County (Southeast) PUMA, Texas',
#   '141127',
#   '48',
#   '04504'],
#  ['Houston-Galveston Area Council--Montgomery County (West)--Conroe City (West) PUMA, Texas',
#   '155111',
#   '48',
#   '04502'],
#  ['Houston-Galveston Area Council--Montgomery County (South)--The Woodlands (North) PUMA, Texas',
#   '118976',
#   '48',
#   '04503'],
#  ['Dallas County (Northeast)--Rowlett & Garland (Northeast) Cities PUMA, Texas',
#   '114081',
#   '48',
#   '02301'],
#  ['Dallas County (Northeast)--Garland (Northwest) & Richardson (East) Cities PUMA, Texas',
#   '110519',
#   '48',
#   '02308'],
#  ['Dallas County (Northwest)--Irving (North), Coppell & Carrollton (Southwest) Cities PUMA; Texas',
#   '120428',
#   '48',
#   '02322'],
#  ['Dallas County (East)--Mesquite City (Central & Southeast) PUMA, Texas',
#   '122701',
#   '48',
#   '02303'],
#  ['Dallas County (Southeast)--Dallas City (Southeast) PUMA, Texas',
#   '114716',
#   '48',
#   '02304'],
#  ['Dallas County (Northwest)--Irving (Central) & Dallas (Northwest) Cities PUMA, Texas',
#   '120020',
#   '48',
#   '02321'],
#  ['Dallas County (Northeast)--Garland City (South) PUMA, Texas',
#   '105942',
#   '48',
#   '02302'],
#  ['Dallas County (West)--Irving (South) & Grand Prairie (North) Cities PUMA, Texas',
#   '106161',
#   '48',
#   '02320'],
#  ['Heart of Texas COG--McLennan County--Waco City (Central) PUMA, Texas',
#   '108342',
#   '48',
#   '03801'],
#  ['Alamo Area COG (Northeast)--Guadalupe County PUMA, Texas',
#   '158966',
#   '48',
#   '05700'],
#  ['Ark-Tex COG (West) PUMA, Texas', '159246', '48', '01000'],
#  ['East Texas COG (Central)--Smith County (Outside Tyler City) PUMA, Texas',
#   '110571',
#   '48',
#   '01501'],
#  ['East Texas COG (Central)--Smith County (West)--Tyler City PUMA, Texas',
#   '116878',
#   '48',
#   '01502'],
#  ['Harris County (North)--Houston City (North)--I-45, Between Beltway TX-8 & FM-1960 PUMA; Texas',
#   '141013',
#   '48',
#   '04626'],
#  ['Harris County (Far North)--Spring PUMA, Texas', '135839', '48', '04627'],
#  ['Harris County (Far Northwest)--Katy City (Northeast) PUMA, Texas',
#   '182699',
#   '48',
#   '04632'],
#  ['Houston-Galveston Area Council--Liberty & Chambers Counties PUMA, Texas',
#   '125007',
#   '48',
#   '04400'],
#  ['Panhandle Regional Planning Commission--Potter County--Amarillo City (North) PUMA, Texas',
#   '119674',
#   '48',
#   '00200'],
#  ['Coastal Bend COG (Southeast) & Willacy County PUMA, Texas',
#   '101243',
#   '48',
#   '06900'],
#  ['Jefferson County (Outside Beaumont City)--Port Arthur City PUMA, Texas',
#   '137551',
#   '48',
#   '04302'],
#  ['Jefferson County (North Central)--Beaumont City PUMA, Texas',
#   '116789',
#   '48',
#   '04301'],
#  ['Johnson County PUMA, Texas', '167212', '48', '02102'],
#  ['South Texas Development Council--Webb County (North & East)--Laredo City (Outer) PUMA, Texas',
#   '141204',
#   '48',
#   '06302'],
#  ['South Texas Development Council (North)--Webb County--Laredo City (Central) PUMA, Texas',
#   '132322',
#   '48',
#   '06301'],
#  ['Tarrant County (Northwest)--Fort Worth (Northwest) & Saginaw Cities PUMA, Texas',
#   '162818',
#   '48',
#   '02516'],
#  ['Tarrant County (West)--Fort Worth City (West) PUMA, Texas',
#   '113213',
#   '48',
#   '02515'],
#  ['Fort Worth City (North Central) & Haltom City (North)--Inside Loop I-820 PUMA, Texas',
#   '112837',
#   '48',
#   '02512'],
#  ['Fort Worth City (North)--East of I-35W & West of US-377 PUMA, Texas',
#   '128866',
#   '48',
#   '02511'],
#  ['Tarrant County (North)--North Richland Hills (North) & Keller Cities PUMA, Texas',
#   '125806',
#   '48',
#   '02510'],
#  ['Tarrant County (Northeast)--Grapevine, Southlake & Colleyville Cities PUMA; Texas',
#   '122687',
#   '48',
#   '02501'],
#  ['Tarrant County (Southwest)--Fort Worth (Southwest) & Benbrook Cities PUMA, Texas',
#   '139855',
#   '48',
#   '02514'],
#  ['Fort Worth (Northeast) & Hurst (South) Cities--North of I-30 PUMA, Texas',
#   '145106',
#   '48',
#   '02509'],
#  ['Tarrant County (East)--Euless (South & West) & Arlington (North) Cities PUMA, Texas',
#   '124691',
#   '48',
#   '02502'],
#  ['Tarrant County (South Central)--Fort Worth City (Southeast)--South of I-20 PUMA, Texas',
#   '125819',
#   '48',
#   '02506'],
#  ['Fort Worth City (South Central) & Edgecliff Village Town PUMA, Texas',
#   '133465',
#   '48',
#   '02513'],
#  ['Fort Worth City (East Central)--South of I-30, East of I-35W & Inside Loop I-820 PUMA; Texas',
#   '117451',
#   '48',
#   '02508'],
#  ['Harris County (North)--Houston (North), Humble Cities & Atascocita PUMA; Texas',
#   '137681',
#   '48',
#   '04625'],
#  ['Houston City (South)--Between Loop I-610 & Beltway TX-8 PUMA, Texas',
#   '132870',
#   '48',
#   '04617'],
#  ['Houston (Southeast) & Webster Cities PUMA, Texas', '116266', '48', '04620'],
#  ['Houston (East), Galena Park, Jacinto Cities & Cloverleaf PUMA; Texas',
#   '115754',
#   '48',
#   '04606'],
#  ['Harris County (Northeast)--Houston City (Far Northeast) PUMA, Texas',
#   '127306',
#   '48',
#   '04624'],
#  ['Harris County (Southeast)--Pasadena City (North & Central)--Inside Beltway TX-8 PUMA, Texas',
#   '121968',
#   '48',
#   '04605'],
#  ['Houston (Southeast), Pasadena (Southeast), La Porte (South) & Seabrook (East) Cities PUMA; Texas',
#   '106958',
#   '48',
#   '04621'],
#  ['Harris County (East)--Deer Park, La Porte (North) Cities & Channelview PUMA; Texas',
#   '113269',
#   '48',
#   '04622'],
#  ['Harris County (East)--Baytown City PUMA, Texas', '113118', '48', '04623'],
#  ['East Texas COG (Northwest)--Van Zandt, Wood, Camp & Rains Counties PUMA; Texas',
#   '124113',
#   '48',
#   '01300'],
#  ['East Texas COG (Southwest)--Henderson & Anderson Counties PUMA, Texas',
#   '138880',
#   '48',
#   '01800'],
#  ['El Paso City (East) PUMA, Texas', '161741', '48', '03302'],
#  ['El Paso City (Central) PUMA, Texas', '99184', '48', '03304'],
#  ['North Texas Regional Planning Commission (Outside Wichita County) & Wise County PUMA, Texas',
#   '155058',
#   '48',
#   '00600'],
#  ['El Paso City (Southeast) PUMA, Texas', '127478', '48', '03303'],
#  ['El Paso County (Outside El Paso City)--Socorro & Horizon Cities PUMA, Texas',
#   '172085',
#   '48',
#   '03301'],
#  ['El Paso City (North) PUMA, Texas', '135794', '48', '03305'],
#  ['El Paso City (Northwest) PUMA, Texas', '139780', '48', '03306'],
#  ['Deep East Texas COG (West) & Walker County PUMA, Texas',
#   '186988',
#   '48',
#   '03900'],
#  ['Coastal Bend COG (Northeast) PUMA, Texas', '131226', '48', '06500'],
#  ['Rio Grande COG & Permian Basin Regional Planning Commission (West) PUMA, Texas',
#   '120446',
#   '48',
#   '03200'],
#  ['West Central Texas COG (Outside Taylor County) PUMA, Texas',
#   '192096',
#   '48',
#   '02600'],
#  ['Concho Valley COG & Permian Basin Regional Planning Commission (East) PUMA, Texas',
#   '102805',
#   '48',
#   '02800'],
#  ['South Texas Development Council (South) & Coastal Bend COG (West) PUMA, Texas',
#   '107794',
#   '48',
#   '06400'],
#  ['Heart of Texas COG (Outside McLennan County) & Navarro County PUMA, Texas',
#   '163383',
#   '48',
#   '03700'],
#  ['West Central Texas COG--Taylor County--Abilene City PUMA, Texas',
#   '136870',
#   '48',
#   '02700'],
#  ['Hunt & Rockwall Counties--Rockwall, Greenville & Dallas (Far Northeast) Cities PUMA; Texas',
#   '191337',
#   '48',
#   '00900'],
#  ['Middle Rio Grande Development Council PUMA, Texas',
#   '172941',
#   '48',
#   '06200'],
#  ['Denton County (East Central)--Frisco (West), The Colony & Little Elm Cities PUMA; Texas',
#   '171653',
#   '48',
#   '02004'],
#  ['Denton County (South Central)--Flower Mound Town & Highland Village City PUMA, Texas',
#   '143703',
#   '48',
#   '02003'],
#  ['Denton County (Central)--Denton (Central) & Corinth Cities PUMA, Texas',
#   '125100',
#   '48',
#   '02005'],
#  ['Denton County (Southeast)--Lewisville City PUMA, Texas',
#   '113035',
#   '48',
#   '02002'],
#  ['Denton County (Far Southeast)--Carrollton (North) & Dallas (North) Cities PUMA, Texas',
#   '127731',
#   '48',
#   '02001'],
#  ['Alamo Area COG (Northwest) & Blanco County PUMA, Texas',
#   '133549',
#   '48',
#   '06000'],
#  ['Deep East Texas COG (East) PUMA, Texas', '115044', '48', '04100'],
#  ['Golden Crescent Regional Planning Commission (North) & Wilson & Karnes Counties PUMA, Texas',
#   '148191',
#   '48',
#   '05500'],
#  ['Tarrant County (Southeast)--Mansfield (North) & Arlington (Southwest) Cities PUMA, Texas',
#   '120638',
#   '48',
#   '02505'],
#  ['Tarrant County (Southeast)--Arlington (Southeast) & Grand Prairie (Southwest) Cities PUMA, Texas',
#   '121268',
#   '48',
#   '02504'],
#  ['Capital Area COG--Williamson County (West)--Cedar Park & Leander Cities PUMA, Texas',
#   '155664',
#   '48',
#   '05204'],
#  ['Capital Area COG--Williamson County (North)--Georgetown (East) & Taylor Cities PUMA, Texas',
#   '141296',
#   '48',
#   '05201'],
#  ['Williamson County (South)--Austin City (Far North), Brushy Creek & Jollyville PUMA; Texas',
#   '118023',
#   '48',
#   '05203'],
#  ['Capital Area COG--Williamson County (Southeast)--Round Rock City PUMA, Texas',
#   '132621',
#   '48',
#   '05202'],
#  ['Houston-Galveston Area Council--Brazoria County (Southwest)--Lake Jackson City PUMA, Texas',
#   '104446',
#   '48',
#   '04803'],
#  ['Houston-Galveston Area Council--Brazoria County (Central)--Alvin City PUMA, Texas',
#   '122633',
#   '48',
#   '04802'],
#  ['Houston-Galveston Area Council--Brazoria County (North)--Pearland City PUMA, Texas',
#   '133598',
#   '48',
#   '04801'],
#  ['South Plains Association of Governments--Lubbock County--Lubbock City (Outer) PUMA, Texas',
#   '190219',
#   '48',
#   '00502'],
#  ['South Plains Association of Governments--Lubbock County--Lubbock City (Central) PUMA, Texas',
#   '114589',
#   '48',
#   '00501'],
#  ['North Texas Regional Planning Commission--Wichita County--Wichita Falls City PUMA, Texas',
#   '131596',
#   '48',
#   '00700'],
#  ['Alamo Area COG (Southwest) PUMA, Texas', '141671', '48', '06100'],
#  ['Central Texas COG--Bell County (North, East & South)--Temple & Belton Cities PUMA; Texas',
#   '177579',
#   '48',
#   '03502'],
#  ['Coastal Bend COG--Nueces County (Central)--Corpus Christi City (South Central) PUMA, Texas',
#   '118679',
#   '48',
#   '06603'],
#  ['Coastal Bend COG--Nueces County (Central)--Corpus Christi City (North Central) PUMA, Texas',
#   '116826',
#   '48',
#   '06602'],
#  ['Coastal Bend COG--Nueces County--Corpus Christi City (Outer) PUMA, Texas',
#   '126035',
#   '48',
#   '06601'],
#  ['Ark-Tex COG (East)--Bowie & Cass Counties PUMA, Texas',
#   '123432',
#   '48',
#   '01100'],
#  ['Ellis County PUMA, Texas', '173772', '48', '02101'],
#  ['North Central Texas COG (West)--Hood, Erath, Palo Pinto & Somervell Counties PUMA; Texas',
#   '137559',
#   '48',
#   '02200'],
#  ['Alamo Area COG (Northeast)--Comal County PUMA, Texas',
#   '141642',
#   '48',
#   '05800'],
#  ['Golden Crescent Regional Planning Commission (Southeast)--Victoria & Calhoun Counties PUMA, Texas',
#   '113777',
#   '48',
#   '05600'],
#  ['Brazos Valley COG (Outside Brazos County) & Milam County PUMA, Texas',
#   '154387',
#   '48',
#   '03601'],
#  ['Houston-Galveston Area Council (West) PUMA, Texas',
#   '181171',
#   '48',
#   '05000'],
#  ['Capital Area COG (Southwest)--Hays County PUMA, Texas',
#   '213366',
#   '48',
#   '05400'],
#  ['San Antonio (Northeast), Kirby & Windcrest Cities PUMA; Texas',
#   '113231',
#   '48',
#   '05913'],
#  ['San Antonio City (Northeast)--Inside Loop I-410 PUMA, Texas',
#   '126316',
#   '48',
#   '05902'],
#  ['San Antonio City (West)--Inside Loop I-410 PUMA, Texas',
#   '121744',
#   '48',
#   '05905'],
#  ['Bexar County (North)--San Antonio City (Far North) & Timberwood Park PUMA, Texas',
#   '115712',
#   '48',
#   '05915'],
#  ['San Antonio City (Central) PUMA, Texas', '109230', '48', '05901'],
#  ['San Antonio (Northwest) & Leon Valley Cities PUMA, Texas',
#   '119071',
#   '48',
#   '05909'],
#  ['Permian Basin Regional Planning Commission (Central)--Midland County--Midland City PUMA, Texas',
#   '168167',
#   '48',
#   '03000'],
#  ['Concho Valley COG--Tom Green County--San Angelo City PUMA, Texas',
#   '117986',
#   '48',
#   '02900'],
#  ['Panhandle Regional Planning Commission--Randall County--Amarillo City (South) PUMA, Texas',
#   '134026',
#   '48',
#   '00300'],
#  ['Cameron County (East)--Brownsville City (North) PUMA, Texas',
#   '130642',
#   '48',
#   '06701'],
#  ['Cameron County (South)--Brownsville City (Central) PUMA, Texas',
#   '143714',
#   '48',
#   '06703'],
#  ['Cameron County (West)--Harlingen & San Benito Cities PUMA, Texas',
#   '147310',
#   '48',
#   '06702'],
#  ['Galveston County (Central, South & East)--Galveston, Texas City & La Marque Cities PUMA; Texas',
#   '165593',
#   '48',
#   '04701'],
#  ['Galveston County (Northwest)--League City & Friendswood City PUMA, Texas',
#   '167292',
#   '48',
#   '04702'],
#  ['Permian Basin Regional Planning Commission (Central)--Ector County--Odessa City PUMA, Texas',
#   '160579',
#   '48',
#   '03100'],
#  ['Capital Area COG (East)--Bastrop, Caldwell, Fayette & Lee Counties PUMA; Texas',
#   '168865',
#   '48',
#   '05100'],
#  ['Denton County (North & West)--Denton City (Outer) PUMA, Texas',
#   '152600',
#   '48',
#   '02006'],
#  ['Dallas (East) & Mesquite (West) Cities--South of I-30 & West of I-635 PUMA, Texas',
#   '136358',
#   '48',
#   '02305'],
#  ['Dallas County (South)--DeSoto & Lancaster Cities PUMA, Texas',
#   '109160',
#   '48',
#   '02317'],
#  ['Dallas (Far North), Carrollton (Southeast) Cities & Addison Town--North of I-635 PUMA; Texas',
#   '122927',
#   '48',
#   '02310'],
#  ['Dallas (Far North) & Richardson (Southwest) Cities PUMA, Texas',
#   '126107',
#   '48',
#   '02309'],
#  ['Dallas City (Northeast)--East of US-75 PUMA, Texas',
#   '131744',
#   '48',
#   '02307'],
#  ['Dallas (Northeast) & Mesquite (North) Cities--North of I-30 & West of I-635 PUMA, Texas',
#   '132104',
#   '48',
#   '02306'],
#  ['Dallas City (East Central)--South of I-30 & East of I-35E PUMA, Texas',
#   '126865',
#   '48',
#   '02314'],
#  ['Dallas County (West)--Grand Prairie (Central) & Dallas (Southwest) Cities PUMA, Texas',
#   '116593',
#   '48',
#   '02319'],
#  ['Dallas (West Central), University Park Cities & Highland Park Town PUMA; Texas',
#   '112939',
#   '48',
#   '02312'],
#  ['Dallas City (North)--South of I-635 & West of US-75 PUMA, Texas',
#   '106805',
#   '48',
#   '02311'],
#  ['Dallas City (South Central)--North of I-20 & West of I-35E PUMA, Texas',
#   '115117',
#   '48',
#   '02316'],
#  ['Dallas County (Southwest)--Cedar Hill & Duncanville Cities PUMA, Texas',
#   '113309',
#   '48',
#   '02318'],
#  ['Dallas City (West Central)--East of Loop TX-12 & West of I-35E PUMA, Texas',
#   '115145',
#   '48',
#   '02315'],
#  ['Dallas City (Downtown)--North of I-30 PUMA, Texas',
#   '126176',
#   '48',
#   '02313'],
#  ['Kaufman County PUMA, Texas', '123804', '48', '01400'],
#  ['Fort Bend County (West & South) PUMA, Texas', '233664', '48', '04905'],
#  ['Fort Bend County (East)--Missouri City PUMA, Texas',
#   '114841',
#   '48',
#   '04901'],
#  ['Fort Bend County (Northeast)--Sugar Land & Stafford Cities PUMA, Texas',
#   '139629',
#   '48',
#   '04902'],
#  ['Fort Bend County (Central)--Rosenberg City, Pecan Grove & New Territory PUMA; Texas',
#   '115350',
#   '48',
#   '04903'],
#  ['Travis County (West, South & Outside Austin City) PUMA; Texas',
#   '140705',
#   '48',
#   '05309'],
#  ['Austin City (Southwest), Lost Creek & Barton Creek PUMA; Texas',
#   '125568',
#   '48',
#   '05308'],
#  ['Austin City (Northwest) PUMA, Texas', '121568', '48', '05305'],
#  ['Austin City (South) PUMA, Texas', '128101', '48', '05307'],
#  ['Austin City (Central) PUMA, Texas', '155047', '48', '05306'],
#  ['Travis County (Northeast)--Pflugerville, Manor Cities & Wells Branch PUMA; Texas',
#   '144785',
#   '48',
#   '05301'],
#  ['Austin City (Southeast) PUMA, Texas', '142034', '48', '05304'],
#  ['Austin City (Northeast) PUMA, Texas', '154717', '48', '05303'],
#  ['Brazos Valley COG--Brazos County--College Station & Bryan Cities PUMA, Texas',
#   '222981',
#   '48',
#   '03602'],
#  ['East Texas COG (Central)--Gregg County--Longview City PUMA, Texas',
#   '123443',
#   '48',
#   '01600'],
#  ['Collin County (Southwest)--Plano City (Central) PUMA, Texas',
#   '112482',
#   '48',
#   '01903'],
#  ['Collin County (Southwest)--Dallas (North), Plano (South) & Richardson (North) Cities PUMA; Texas',
#   '125827',
#   '48',
#   '01901'],
#  ['Collin County (Southwest)--Plano City (West) PUMA, Texas',
#   '118240',
#   '48',
#   '01902'],
#  ['Collin County (South Central)--Allen, Murphy, Plano (East) & Parker Cities PUMA; Texas',
#   '142035',
#   '48',
#   '01904'],
#  ['Collin County (Central)--McKinney City PUMA, Texas',
#   '152127',
#   '48',
#   '01905'],
#  ['Collin County (Northwest)--Frisco City (East) & Prosper Town PUMA, Texas',
#   '176427',
#   '48',
#   '01906'],
#  ['Collin County (East) PUMA, Texas', '147790', '48', '01907'],
#  ['Houston (West) & Hunters Creek Village Cities--Between Loop I-610 & Beltway TX-8 PUMA, Texas',
#   '118629',
#   '48',
#   '04613'],
#  ['Houston City (Northwest)--Between Loop I-610 & Beltway TX-8 PUMA, Texas',
#   '113076',
#   '48',
#   '04611'],
#  ['Harris County (Northwest)--North of US-290 & North of FM-1960 PUMA, Texas',
#   '130034',
#   '48',
#   '04631'],
#  ['Houston (West) & Spring Valley Village Cities--Between Loop I-610 & Beltway TX-8 PUMA, Texas',
#   '107836',
#   '48',
#   '04612'],
#  ['Harris County (Northwest)--Jersey Village City--Between Beltway TX-8 & FM-1960 PUMA, Texas',
#   '113468',
#   '48',
#   '04628'],
#  ['Harris County (Northwest)--South of US-290 & West of TX-6 PUMA, Texas',
#   '112100',
#   '48',
#   '04633'],
#  ['East Texas COG (Northeast)--Harrison, Upshur & Marion Counties PUMA; Texas',
#   '117615',
#   '48',
#   '01200'],
#  ['Houston City (West)--East of TX-6 & West of Beltway TX-8 PUMA, Texas',
#   '114064',
#   '48',
#   '04636'],
#  ['Houston City (West)--Westpark Tollway, West of Beltway TX-8 PUMA; Texas',
#   '127290',
#   '48',
#   '04637'],
#  ['Houston City (West)--Westpark Tollway, Between Loop I-610 & Beltway TX-8 PUMA; Texas',
#   '114831',
#   '48',
#   '04614'],
#  ['Houston City (North)--South of Aldine & Inside Beltway TX-8 PUMA, Texas',
#   '132185',
#   '48',
#   '04609'],
#  ['Harris County (North)--North of FM-1960, West of I-45 & East of TX-249 PUMA; Texas',
#   '124264',
#   '48',
#   '04629'],
#  ['Harris County (Far North)--Tomball City & The Woodlands (Southwest) PUMA, Texas',
#   '151992',
#   '48',
#   '04630'],
#  ['Harris County (West)--Houston City (West)--North of US-90 & West of TX-6 PUMA, Texas',
#   '120786',
#   '48',
#   '04634'],
#  ['Houston (Southwest) & Bellaire (Southeast) Cities--Between Loop I-610 & Beltway TX-8 PUMA, Texas',
#   '106576',
#   '48',
#   '04615'],
#  ['Houston City (North)--West of Aldine & Inside Beltway TX-8 PUMA, Texas',
#   '116000',
#   '48',
#   '04610'],
#  ['Houston City (West)--South of I-10 & West of TX-6 PUMA, Texas',
#   '117392',
#   '48',
#   '04635'],
#  ['Houston City (Southwest)--East of TX-6 & West of Beltway TX-8 PUMA, Texas',
#   '116459',
#   '48',
#   '04638'],
#  ['Houston City (West Central)--South of I-10 & Inside Loop I-610 PUMA, Texas',
#   '143605',
#   '48',
#   '04604'],
#  ['Panhandle Regional Planning Commission (Outside Potter & Randall Counties) PUMA, Texas',
#   '182075',
#   '48',
#   '00100'],
#  ['Bexar County (South)--San Antonio City (Far South) PUMA, Texas',
#   '121853',
#   '48',
#   '05907'],
#  ['Bexar County (Northwest)--San Antonio (Far Northwest) & Helotes Cities PUMA, Texas',
#   '146282',
#   '48',
#   '05914'],
#  ['San Antonio City (Southeast)--Inside Loop I-410 PUMA, Texas',
#   '125596',
#   '48',
#   '05903'],
#  ['San Antonio City (Southwest)--Inside Loop I-410 PUMA, Texas',
#   '129969',
#   '48',
#   '05906'],
#  ['Bexar County (Northeast)--San Antonio (Northeast), Universal City & Converse Cities PUMA; Texas',
#   '118090',
#   '48',
#   '05916'],
#  ['Tarrant County (East)--Arlington City (West)--South of I-30 & East of Loop I-820 PUMA, Texas',
#   '120666',
#   '48',
#   '02507'],
#  ['Tarrant County (East)--Arlington (East) & Grand Prairie (West Central) Cities PUMA, Texas',
#   '134584',
#   '48',
#   '02503'],
#  ['Houston City (South Central)--South of US-59, West of I-45 & Inside Loop I-610 PUMA; Texas',
#   '125137',
#   '48',
#   '04603'],
#  ['Houston City (North Central)--North of I-10 & Inside Loop I-610 PUMA, Texas',
#   '116276',
#   '48',
#   '04601'],
#  ['Houston City (Northeast)--Between Loop I-610 & Beltway TX-8 PUMA, Texas',
#   '122593',
#   '48',
#   '04607'],
#  ['Houston (Southeast) & South Houston Cities--Inside Beltway TX-8 PUMA, Texas',
#   '115657',
#   '48',
#   '04619'],
#  ['Houston City (Southeast)--West of Pasadena City & Outside Loop I-610 PUMA, Texas',
#   '107745',
#   '48',
#   '04618'],
#  ['Houston City (East Central)--East of I-45 & Inside Loop I-610 PUMA, Texas',
#   '112665',
#   '48',
#   '04602']]
